# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
import pybaseball as pb
import seaborn as sns

# %%
data = pb.statcast(start_dt = '2023-01-01', end_dt = '2025-12-31')

# %%
data.to_csv('statcast_2023_2025.csv')
